# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("E:\\TECHSTACK\\fortune1000_2024.csv")

# %%
df = data.copy()

# %%
df.head()
# Out:
#    Rank             Company Ticker       Sector  \
# 0     1             Walmart    WMT    Retailing
# 1     2              Amazon   AMZN    Retailing
# 2     3               Apple   AAPL   Technology
# 3     4  UnitedHealth Group    UNH  Health Care
# 4     5  Berkshire Hathaway   BRKA   Financials
#
#                                    Industry Profitable Founder_is_CEO  \
# 0                     General Merchandisers        yes             no
# 1           Internet Services and Retailing        yes             no
# 2               Computers, Office Equipment        yes             no
# 3   Health Care: Insurance and Managed Care        yes             no
# 4  Insurance: Property and Casualty (Stock)        yes             no
#
#   FemaleCEO Growth_in_Jobs  Change_in_Rank  ...   Assets_M  \
# 0        no             no             0.0  ...   252399.0
# 1        no             no             0.0  ...   527854.0
# 2        no             no             1.0  ...   352583.0
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Company', 'Ticker', 'Sector', 'Industry', 'Profitable',
#        'Founder_is_CEO', 'FemaleCEO', 'Growth_in_Jobs', 'Change_in_Rank',
#        'Gained_in_Rank', 'Dropped_in_Rank', 'Newcomer_to_the_Fortune500',
#        'Global500', 'Worlds_Most_Admired_Companies',
#        'Best_Companies_to_Work_For', 'Number_of_employees',
#        'MarketCap_March28_M', 'Revenues_M', 'RevenuePercentChange',
#        'Profits_M', 'ProfitsPercentChange', 'Assets_M', 'CEO', 'Country',
#        'HeadquartersCity', 'HeadquartersState', 'Website', 'CompanyType',
#        'Footnote', 'MarketCap_Updated_M', 'Updated'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Rank                               0
# Company                            0
# Ticker                            41
# Sector                             0
# Industry                           0
# Profitable                         0
# Founder_is_CEO                     0
# FemaleCEO                          0
# Growth_in_Jobs                     0
# Change_in_Rank                     0
# Gained_in_Rank                     0
# Dropped_in_Rank                    0
# Newcomer_to_the_Fortune500       500
# Global500                          0
# Worlds_Most_Admired_Companies      0
# Best_Companies_to_Work_For         0
# Number_of_employees                0
# MarketCap_March28_M               41
# Revenues_M                         0
# RevenuePercentChange               6
# Profits_M                          2
# ProfitsPercentChange             150
# Assets_M                           0
# CEO                                0
# Country                            0
# ...

# %%
df.describe().T
# Out:
#                        count          mean            std      min       25%  \
# Rank                  1000.0    500.498000     288.819686      1.0   250.750
# Change_in_Rank        1000.0      5.838000      66.880840   -577.0   -14.000
# Number_of_employees   1000.0  36611.758000   99900.995589     28.0  6718.000
# MarketCap_March28_M    959.0  50838.898749  191357.697577      1.2  4862.750
# Revenues_M            1000.0  20965.064200   48589.311028   2489.0  3968.375
# RevenuePercentChange   994.0      6.788129      34.918519    -78.3    -4.700
# Profits_M              998.0   1867.165832    6649.887738 -10298.0   157.575
# ProfitsPercentChange   850.0      3.348706     938.609539 -22340.0   -37.575
# Assets_M              1000.0  63757.219100  272155.139972    361.3  5342.950
# MarketCap_Updated_M    963.0  53974.445483  229266.432765      1.0  4832.500
#
#                            50%        75%        max
# Rank                    500.50    750.250     1000.0
# ...

# %% [markdown]
# # Top 10 Revenue Giants in the Fortune 1000

# %%
df1 = df[["Company","Revenues_M"]].sort_values(by = "Revenues_M", ascending=False).head(10)
df1
# Out:
#               Company  Revenues_M
# 0             Walmart    648125.0
# 1              Amazon    574785.0
# 2               Apple    383285.0
# 3  UnitedHealth Group    371622.0
# 4  Berkshire Hathaway    364482.0
# 5          CVS Health    357776.0
# 6         Exxon Mobil    344582.0
# 7            Alphabet    307394.0
# 8            McKesson    276711.0
# 9             Cencora    262173.4

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = "Company", y = "Revenues_M", data = df1, palette = "viridis")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# # Top 30 companies with the lowest Profits in the Fortune 1000

# %%
#creating a new df to exclude NaN values
df3 = df.fillna(0)
x = (df3["Profits_M"] == 0)
df3 = df3.loc[~x]


df2 = df3.groupby("Company")["Profits_M"].mean().reset_index(name = "profit_m")


df2 = df2.sort_values(by = "profit_m", ascending = False).tail(30)


plt.figure(figsize = (8,6))

sns.barplot(x = "Company", y = "profit_m", data = df2, palette = "viridis")
plt.tight_layout()
plt.xticks(rotation = 90)

plt.show()

# %%
df["Sector"].value_counts()
# Out:
# Sector
# Financials                       163
# Technology                       115
# Energy                           107
# Health Care                       80
# Retailing                         72
# Business Services                 59
# Industrials                       48
# Materials                         47
# Transportation                    39
# Food, Beverages & Tobacco         35
# Engineering & Construction        31
# Wholesalers                       30
# Hotels, Restaurants & Leisure     29
# Chemicals                         26
# Media                             26
# Motor Vehicles & Parts            21
# Household Products                20
# Aerospace & Defense               19
# Apparel                           15
# Food & Drug Stores                 9
# Telecommunications                 9
# Name: count, dtype: int64

# %% [markdown]
# # Top 10 Sectors by Company Count in the Fortune 1000

# %%
df["Sector"].value_counts().head(10).plot(kind = "pie", autopct = ""%.1f")
plt.ylabel(None)
plt.show()

# %% [markdown]
# # Top 10 Most Profitable Sectors in the Fortune 1000

# %%
df4 = df.groupby("Sector")["Profits_M"].sum().sort_values(ascending = False).head(10)
df4
# Out:
# Sector
# Technology                   453298.9
# Financials                   418658.6
# Energy                       240145.3
# Health Care                  166728.1
# Retailing                    112801.9
# Industrials                   77169.5
# Food, Beverages & Tobacco     67468.8
# Business Services             60770.1
# Transportation                39138.2
# Telecommunications            33541.1
# Name: Profits_M, dtype: float64

# %%
sns.barplot(x = df4.values, y = df4.index, palette = "viridis")
# Out:
# <Axes: ylabel='Sector'>

# %% [markdown]
# # Top 10 Companies with the Largest Workforces in the Fortune 1000

# %%
df5 = df[["Company","Number_of_employees"]].sort_values(by = "Number_of_employees", ascending = False).head(10)
df5
# Out:
#                    Company  Number_of_employees
# 0                  Walmart              2100000
# 1                   Amazon              1525000
# 22              Home Depot               463100
# 45                   FedEx               446400
# 498             Concentrix               440000
# 3       UnitedHealth Group               440000
# 36                  Target               415000
# 24                  Kroger               414000
# 4       Berkshire Hathaway               396500
# 44   United Parcel Service               382550

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = "Company", y = "Number_of_employees", data = df5, palette = "viridis")
plt.ticklabel_format(style="plain", axis="y")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Public Vs Private Companies in the Fortune 1000

# %%
df["CompanyType"].value_counts().plot(kind = "pie", autopct = "%.2f", )
plt.ylabel(None)
plt.show()

# %% [markdown]
# # Top Preferred Locations for the Headquaters in the Fortune 1000

# %%
df7 = df["HeadquartersCity"].value_counts().head(20)
df7
# Out:
# HeadquartersCity
# New York         61
# Houston          36
# Atlanta          24
# Chicago          24
# Dallas           21
# San Francisco    19
# Columbus         14
# Charlotte        13
# St. Louis        13
# Denver           12
# Irving           12
# San Jose         11
# San Diego        10
# Boston           10
# Stamford          9
# Santa Clara       9
# Seattle           9
# Richmond          9
# Pittsburgh        9
# Cleveland         9
# Name: count, dtype: int64

# %%
sns.barplot(x = df7.values, y = df7.index, palette = "viridis")
plt.show()

# %% [markdown]
# # Profitability Snapshot: Count of Profitable Vs Non-Profitable Companies in the Fortune 1000

# %%
sns.countplot(y="Profitable",data=df)
plt.show()

# %% [markdown]
# # Founder-Led Companies: CEO Status in the Fortune 1000

# %%
sns.countplot(y="Founder_is_CEO",data=df)
plt.show()

# %% [markdown]
# # Representation of Female CEOs in the Fortune 1000

# %%
sns.countplot(y="FemaleCEO",data=df)
plt.show()

# %% [markdown]
# # Profitability Comparison: Female-Led vs. Male-Led Companies in the Fortune 1000

# %%
df8 = df.groupby(["FemaleCEO", "Profitable"]).size().reset_index(name="Count")
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x="Profitable", y="Count", hue="FemaleCEO", data=df8)
plt.show()

# %% [markdown]
# # Revenue vs. Profit Analysis with Profitability Status in the Fortune 1000

# %%
sns.scatterplot(data=df3, x="Revenues_M", y="Profits_M", hue="Profitable")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# # Revenue vs. Profit Analysis: Impact of Founder-CEO Leadership in the Fortune 1000

# %%
sns.scatterplot(data=df3, x="Revenues_M", y="Profits_M", hue="Founder_is_CEO")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# # Revenue vs. Profit Analysis: Influence of Female CEOs in the Fortune 1000

# %%
sns.scatterplot(data=df3, x="Revenues_M", y="Profits_M", hue="FemaleCEO")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# # Conclusion and Insights:

# %% [markdown]
# Conclusions and Insights
#
# 1- Revenue Giants in the Fortune 1000: The top three revenue-generating companies are Walmart, Amazon, and Apple. These companies significantly outpace others in terms of revenue, establishing themselves as leaders in their respective industries.
#
# 2- Companies with the Lowest Profits: Lumen Technologies leads the list of the 30 companies with the lowest profits, followed closely by 3M and Fidelity National Information Services. This highlights the challenges faced by these companies, despite their prominence.
#
# 3- Sector Representation by Company Count: Financials, Technology, and Energy sectors dominate the Fortune 1000, with the most companies represented. This indicates the broad reach and influence of these sectors in the corporate landscape.
#
# 4- Most Profitable Sectors: The Technology sector tops the list of the most profitable sectors, followed by Financials and Energy. This aligns with the dominance of these sectors in revenue generation and their pivotal role in the economy.
#
# 5- Companies with the Largest Workforces: Walmart, Amazon, and Home Depot are the top three employers among the Fortune 1000 companies. The significant workforce sizes reflect the operational scale and market reach of these retail giants.
#
# 6- Public vs. Private Companies: A vast majority (95.50%) of the Fortune 1000 companies are public, with only a small fraction being private. This underscores the importance of public markets for large-scale enterprises.
#
# 7- Preferred Headquarters Locations: New York City is the most preferred location for company headquarters, with 61 companies based there. Houston and Atlanta also emerge as popular choices, hosting 36 and 24 companies, respectively.
#
# 8- Profitability Among Fortune 1000 Companies: A large proportion of companies in the Fortune 1000 are profitable, indicating a generally healthy financial environment among these top firms.
#
# 9- Founder-Led Companies: Very few companies in the Fortune 1000 are still led by their founders. This suggests a trend where founders often step aside as companies grow and mature.
#
# 10- Female Leadership in the Fortune 1000: More than 80% of the companies are not led by female CEOs, highlighting the ongoing gender disparity in corporate leadership.
#
# 11- Profitability Comparison: Female-Led vs. Male-Led Companies: The analysis shows a comparison between female-led and male-led companies in terms of profitability. This comparison sheds light on the financial performance of companies based on the gender of their leadership.
#
# 12- Revenue vs. Profit Analysis with Profitability: The scatter plot reveals that companies with lower revenue are more likely to be loss-making, suggesting a correlation between revenue size and profitability.
#
# 13- Revenue vs. Profit Analysis with Founder-CEO Leadership: The scatter plot indicates the impact of having a founder as the CEO on revenue and profit, providing insights into the effectiveness of founder-led leadership in driving financial performance.
#
# 14- Revenue vs. Profit Analysis with Female CEO Leadership: This analysis explores how female leadership correlates with revenue and profit, offering a perspective on the financial success of companies with female CEOs.
